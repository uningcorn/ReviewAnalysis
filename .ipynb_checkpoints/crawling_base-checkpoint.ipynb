# %% [markdown]
# headers={"User-Agent"~~}를 사용하였다.

# %%
from bs4 import BeautifulSoup
import requests
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
import time
import pandas as pd

# %%
# 얘는 지금 내가 실행이 안됨
# from selenium.webdriver.chrome.service import Service
# from webdriver_manager.chrome import ChromeDriverManager
# 
# def set_chrome_driver():
#     chrome_options = webdriver.ChromeOptions()
#     driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
#     return driver

# driver = set_chrome_driver()
# driver.get('https://www.naver.com')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 from selenium.webdriver.chrome.service import Service
# ----> 2 from webdriver_manager.chrome import ChromeDriverManager
#       4 def set_chrome_driver():
#       5     chrome_options = webdriver.ChromeOptions()
#
# ModuleNotFoundError: No module named 'webdriver_manager'

# %%
from selenium import webdriver

driver = webdriver.Chrome()
driver.get('https://www.naver.com')

# %%
# 드라이버 테스트 

driver = webdriver.Chrome()
driver.implicitly_wait(10) # 10초 대기

driver.get('https://google.co.kr')

time.sleep(5) # 5초 대기
driver.quit() # 웹 브라이저 종료 driver.close() 탭 종료

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import time

# %%
# ChromeOptions 설정
chrome_options = Options()
chrome_options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36")  # User-Agent 설정
#chrome_options.add_argument("--headless")  # 브라우저 창을 띄우지 않고 실행 (필요시 주석 처리)

# Chrome 드라이버 설정
service = Service('/path/to/chromedriver')  # chromedriver 경로 설정
driver = webdriver.Chrome(service=service, options=chrome_options)

driver.implicitly_wait(10)

# %%
# 접속, 팝업삭제, 랭킹페이지 소스코드 가지고 오기
driver = webdriver.Chrome()
driver.implicitly_wait(10) # 10초 대기

url = 'https://www.musinsa.com/main/musinsa/ranking?storeCode=musinsa&sectionId=199&categoryCode=100000&period=MONTHLY'
driver.get(url)
time.sleep(3) # 3초 대기

try:
    popup = driver.find_element(By.CSS_SELECTOR, 'div._gateway-additional_3fnt1_52 button')
    popup.click()
    time.sleep(3)
except:
    print('팝업창 없음')

html = driver.page_source
soup = BeautifulSoup(html, 'lxml')
driver.quit()

# %%
# 랭킹에 있는 url 가져오기
product_links = []

for link in soup.select('.sc-1m4cyao-1 a'):
    product_url = link.get('href')
    product_links.append(product_url)

df = pd.DataFrame(product_links, columns=['URL'])
df['review URL'] = df['URL'].str.replace('/app/goods/', '/review/goods/') #리뷰페이지로 바로가는 주소 확보

csv_filename = 'musinsa_crawling_linklist.csv'
df.to_csv(csv_filename, index=False)

# %%
df
# Out:
#                                            URL  \
# 0    https://www.musinsa.com/app/goods/1875663
# 1    https://www.musinsa.com/app/goods/3977452
# 2    https://www.musinsa.com/app/goods/1875664
# 3    https://www.musinsa.com/app/goods/4018731
# 4    https://www.musinsa.com/app/goods/3977488
# ..                                         ...
# 195  https://www.musinsa.com/app/goods/4101470
# 196  https://www.musinsa.com/app/goods/3971202
# 197  https://www.musinsa.com/app/goods/4056085
# 198  https://www.musinsa.com/app/goods/4108244
# 199  https://www.musinsa.com/app/goods/2416846
#
#                                        review URL
# 0    https://www.musinsa.com/review/goods/1875663
# 1    https://www.musinsa.com/review/goods/3977452
# 2    https://www.musinsa.com/review/goods/1875664
# 3    https://www.musinsa.com/review/goods/4018731
# 4    https://www.musinsa.com/review/goods/3977488
# ..                                            ...
# 195  https://www.musinsa.com/review/goods/4101470
# 196  https://www.musinsa.com/review/goods/3971202
# 197  https://www.musinsa.com/review/goods/4056085
# 198  https://www.musinsa.com/review/goods/4108244
# 199  https://www.musinsa.com/review/goods/2416846
#
# [200 rows x 2 columns]

# %%
reviews = []

for product_url in product_links:
    driver.get(product_url)
    time.sleep(3)

    html = driver.page_source
    soup = BeautifulSoup(html, 'lxml')

# %%
# 한 페이지에서 html 소스코드 가져오기
driver = webdriver.Chrome()
driver.implicitly_wait(10) 

product_url = 'https://www.musinsa.com/products/1875663'
driver.get(product_url)
time.sleep(3)

html = driver.page_source
soup = BeautifulSoup(html, 'lxml')
driver.quit()

# %%
brandname = soup.select('.text-sm')
brandname[0].text
# Out:
# '무신사 스탠다드 우먼'

# %%
count = soup.select('.text-etc_11px_reg')
review_count = count[4].text
review_count = review_count.replace(',', '')
review_count = int(review_count)
review_count
# Out:
# 2127

# %%
# 한 페이지_상품후기더보기에서 html 소스코드 가져오기
driver = webdriver.Chrome()
driver.implicitly_wait(10) 

product_url = 'https://www.musinsa.com/review/goods/1875663'
driver.get(product_url)
time.sleep(3)

detail_html = driver.page_source
soup = BeautifulSoup(detail_html, 'lxml')
driver.quit()

# %%
# 제목만 선택하기
title = soup.select_one('.sc-eulNPF')
title.text
# Out:
# '[쿨탠다드] 우먼즈 피케 폴로 원피스 [블랙]'

# %%
brand = soup.select_one('.sc-11x022e-2')
print(brand)
# Out:
# None

# %%
revi = soup.select(".sc-bbSYpP p")
revi
# Out:
# [<p class="text-body_13px_reg sc-cwHqhk jfrxJQ font-pretendard">XS사려다 S샀는데 XS살걸ㅠㅜㅜ
#  우선 다른 피케원피스보다 기장이 길었고
#  시원한 재질이여서 손이 잘 가요!
#  단정한 느낌도 줘서 굿~!</p>,
#  <p class="text-body_13px_reg sc-cwHqhk jfrxJQ font-pretendard">키가 매우매우 크기 때무네 저에게는 미니기장이긴 한데 짧을건 이미 예상하고 구매했습니다! 근데도 너무 예뻐요ㅠ상체 퉁퉁이인데 팔뚝살 잘 감춰주고 단추 오픈해서 입으면 그나마 덜 퉁퉁이로 보여서 너무 좋아요ㅠㅜ 얇아서 좀 비치긴 하지만 속바지 or 속치마 입으면 갠춘합니당ㅎㅎ다른색도 살까 고민중이에요ㅜㅠ너무 예뻐,,</p>,
#  <p class="text-body_13px_reg sc-cwHqhk jfrxJQ font-pretendard">네이비랑 블랙 고밈하다가 블랙구매했어요
#  허리 잘록하게 잘들어가고 핏이뻐요
#  다만 많이 비치는거같아서 신경써야할거같아요</p>,
#  <p class="text-body_13px_reg sc-cwHqhk jfrxJQ font-pretendard">처음에 s살까 xs살까 고민하다가 xs샀어요!!!
#  질도 좋고 예뻐요 네이비도 살까봐여,,,</p>,
#  <p class="text-body_13px_reg sc-cwHqhk jfrxJQ font-pretendard">많이 짧지도 않고 깔끔한 핏에 허리라인이 살짝 들어가서 예뻐요.
#  옷감이 얇아서 밝은데서 보면 원피스 속 다리 라인이 비쳐보여서 속치마를 입는게 좋을듯 해요!
#  다른 컬러도 살예정ㅋㅋ</p>,
#  <p class="text-body_13px_reg sc-cwHqhk jfrxJQ font-pretendard">통통한 편인데 엠사이즈 잘맞아요
#  딱 기본 스타일이라서 매우 맘에 듭니다</p>]

# %%
star = soup.select_one('.text-body_14px_semi')
star.text
# Out:
# '5.0'

# %%
# 리뷰수 카운트하기
count = soup.select('.text-title_18px_med')
review_text = count[0].text
review_count = extract_review_count(review_text)
review_count
# Out:
# 2089

# %%
# 숫자만 남기고 없애기
match = re.search(r'\d+', review_text)
if match:
    review_count = int(match.group())
else:
    review_count = 0

print(review_count)
# Out:
# 2089

# %%
# 상품후기 개수 숫자로 바꾸기 함수화
def extract_review_count(text):
    text = text.replace(',', '')
    
    match = re.search(r'\d+', text)
    
    if match:
        review_count = int(match.group())
    else:
        review_count = 0

    return review_count

# %%
# 리뷰 가지고 오기 테스트
detail_review = soup.select('p')
filtered_reviews = []

for review in detail_review:
    # 특정 클래스가 포함된 요소만 유의미한 리뷰로 간주
    if "text-body_13px_reg" in review.get('class', []):
        filtered_reviews.append(review.text.strip())

for review in filtered_reviews:
    print(review)
    print('---')
# Out:
# XS사려다 S샀는데 XS살걸ㅠㅜㅜ
# 우선 다른 피케원피스보다 기장이 길었고
# 시원한 재질이여서 손이 잘 가요!
# 단정한 느낌도 줘서 굿~!
# ---
# 키가 매우매우 크기 때무네 저에게는 미니기장이긴 한데 짧을건 이미 예상하고 구매했습니다! 근데도 너무 예뻐요ㅠ상체 퉁퉁이인데 팔뚝살 잘 감춰주고 단추 오픈해서 입으면 그나마 덜 퉁퉁이로 보여서 너무 좋아요ㅠㅜ 얇아서 좀 비치긴 하지만 속바지 or 속치마 입으면 갠춘합니당ㅎㅎ다른색도 살까 고민중이에요ㅜㅠ너무 예뻐,,
# ---
# 네이비랑 블랙 고밈하다가 블랙구매했어요
# 허리 잘록하게 잘들어가고 핏이뻐요
# 다만 많이 비치는거같아서 신경써야할거같아요
# ---
# 처음에 s살까 xs살까 고민하다가 xs샀어요!!!
# 질도 좋고 예뻐요 네이비도 살까봐여,,,
# ---
# 많이 짧지도 않고 깔끔한 핏에 허리라인이 살짝 들어가서 예뻐요.
# 옷감이 얇아서 밝은데서 보면 원피스 속 다리 라인이 비쳐보여서 속치마를 입는게 좋을듯 해요!
# 다른 컬러도 살예정ㅋㅋ
# ---
# 통통한 편인데 엠사이즈 잘맞아요
# 딱 기본 스타일이라서 매우 맘에 듭니다
# ---

# %%
review_elements = soup.select('.text-body_13px_reg')
review_elements
# Out:
# [<span class="text-body_13px_reg text-gray-500 font-pretendard">옵션</span>,
#  <span class="text-body_13px_reg text-gray-500 font-pretendard">성별</span>,
#  <span class="text-body_13px_reg text-gray-500 font-pretendard">키/몸무게</span>,
#  <span class="text-body_13px_reg text-gray-500 font-pretendard">후기유형</span>,
#  <label class="text-body_13px_reg text-nowrap disabled:text-gray-400 peer-disabled:text-gray-400 peer-disabled:cursor-not-allowed group-data-[disabled]:text-gray-400 peer-data-[state=checked]:text-black peer-data-[state=unchecked]:text-gray-600 peer-data-[state=unchecked]:peer-disabled:text-gray-400 peer-data-[state=checked]:peer-disabled:text-gray-600 peer-[[role=switch]]:text-gray-600 peer-[[role=switch]]:peer-data-[state=checked]:text-black peer-[[role=switch]]:peer-data-[state=unchecked]:peer-disabled:text-gray-400 peer-[[role=switch]]:peer-data-[state=checked]:peer-disabled:text-gray-600 sc-bDoQz iRsslS" for="similar-body-shape-switch">나와 비슷한 체형 </label>,
#  <span class="text-body_13px_reg text-gray-500 font-pretendard">유용한순</span>,
#  <span class="text-body_13px_reg text-gray-600 font-pretendard">여성</span>,
#  <span class="text-body_13px_reg text-gray-600 font-pretendard">165(cm)</span>,
#  <span class="text-body_13px_reg text-gray-600 font-pretendard">45(kg)</span>,
#  <span class="text-body_13px_reg text-gray-600 font-pretendard">/</span>,
#  <span class="text-body_13px_reg text-gray-600 font-pretendard">S 구매</span>,
#  <span class="text-body_13px_reg sc-fXSgRJ fCtvvK text-gray-600 font-pretendard">21.08.19</span>,
#  <p class="text-body_13px_reg sc-cwHqhk jfrxJQ font-pretendard">XS사려다 S샀는데 XS살걸ㅠㅜㅜ
#  우선 다른 피케원피스보다 기장이 길었고
#  시원한 재질이여서 손이 잘 가요!
#  단정한 느낌도 줘서 굿~!</p>,
#  <span class="text-body_13px_reg sc-jEABJj eDGVAa gtm-click-button text-gray-600 font-pretendard" data-brand-id="(not set)" data-button-id="review_more" data-button-name="후기내용더보기" data-index="(not set)" data-section-index="6" data-section-name="review">... <span class="underline">더보기</span></span>,
#  <span class="text-body_13px_reg font-pretendard">50</span>,
#  <span class="text-body_13px_reg font-pretendard">0</span>,
#  <span class="text-body_13px_reg text-gray-600 font-pretendard">여성</span>,
#  <span class="text-body_13px_reg text-gray-600 font-pretendard">178(cm)</span>,
#  <span class="text-body_13px_reg text-gray-600 font-pretendard">65(kg)</span>,
#  <span class="text-body_13px_reg text-gray-600 font-pretendard">/</span>,
#  <span class="text-body_13px_reg text-gray-600 font-pretendard">L 구매</span>,
#  <span class="text-body_13px_reg sc-fXSgRJ fCtvvK text-gray-600 font-pretendard">22.05.11</span>,
#  <p class="text-body_13px_reg sc-cwHqhk jfrxJQ font-pretendard">키가 매우매우 크기 때무네 저에게는 미니기장이긴 한데 짧을건 이미 예상하고 구매했습니다! 근데도 너무 예뻐요ㅠ상체 퉁퉁이인데 팔뚝살 잘 감춰주고 단추 오픈해서 입으면 그나마 덜 퉁퉁이로 보여서 너무 좋아요ㅠㅜ 얇아서 좀 비치긴 하지만 속바지 or 속치마 입으면 갠춘합니당ㅎㅎ다른색도 살까 고민중이에요ㅜㅠ너무 예뻐,,</p>,
#  <span class="text-body_13px_reg sc-jEABJj eDGVAa gtm-click-button text-gray-600 font-pretendard" data-brand-id="(not set)" data-button-id="review_more" data-button-name="후기내용더보기" data-index="(not set)" data-section-index="6" data-section-name="review">... <span class="underline">더보기</span></span>,
#  <span class="text-body_13px_reg font-pretendard">49</span>,
#  <span class="text-body_13px_reg font-pretendard">0</span>,
#  <span class="text-body_13px_reg text-gray-600 font-pretendard">여성</span>,
#  <span class="text-body_13px_reg text-gray-600 font-pretendard">160(cm)</span>,
#  <span class="text-body_13px_reg text-gray-600 font-pretendard">45(kg)</span>,
#  <span class="text-body_13px_reg text-gray-600 font-pretendard">/</span>,
#  <span class="text-body_13px_reg text-gray-600 font-pretendard">S 구매</span>,
#  <span class="text-body_13px_reg sc-fXSgRJ fCtvvK text-gray-600 font-pretendard">21.09.01</span>,
#  <p class="text-body_13px_reg sc-cwHqhk jfrxJQ font-pretendard">네이비랑 블랙 고밈하다가 블랙구매했어요
#  허리 잘록하게 잘들어가고 핏이뻐요
#  다만 많이 비치는거같아서 신경써야할거같아요</p>,
#  <span class="text-body_13px_reg font-pretendard">39</span>,
#  <span class="text-body_13px_reg font-pretendard">0</span>,
#  <span class="text-body_13px_reg text-gray-600 font-pretendard">여성</span>,
#  <span class="text-body_13px_reg text-gray-600 font-pretendard">162(cm)</span>,
#  <span class="text-body_13px_reg text-gray-600 font-pretendard">49(kg)</span>,
#  <span class="text-body_13px_reg text-gray-600 font-pretendard">/</span>,
#  <span class="text-body_13px_reg text-gray-600 font-pretendard">XS 구매</span>,
#  <span class="text-body_13px_reg sc-fXSgRJ fCtvvK text-gray-600 font-pretendard">21.04.16</span>,
#  <p class="text-body_13px_reg sc-cwHqhk jfrxJQ font-pretendard">처음에 s살까 xs살까 고민하다가 xs샀어요!!!
#  질도 좋고 예뻐요 네이비도 살까봐여,,,</p>,
#  <span class="text-body_13px_reg font-pretendard">33</span>,
#  <span class="text-body_13px_reg font-pretendard">0</span>,
#  <span class="text-body_13px_reg text-gray-600 font-pretendard">여성</span>,
#  <span class="text-body_13px_reg text-gray-600 font-pretendard">166(cm)</span>,
#  <span class="text-body_13px_reg text-gray-600 font-pretendard">53(kg)</span>,
#  <span class="text-body_13px_reg text-gray-600 font-pretendard">/</span>,
#  <span class="text-body_13px_reg text-gray-600 font-pretendard">S 구매</span>,
#  <span class="text-body_13px_reg sc-fXSgRJ fCtvvK text-gray-600 font-pretendard">21.04.25</span>,
#  <p class="text-body_13px_reg sc-cwHqhk jfrxJQ font-pretendard">많이 짧지도 않고 깔끔한 핏에 허리라인이 살짝 들어가서 예뻐요.
#  옷감이 얇아서 밝은데서 보면 원피스 속 다리 라인이 비쳐보여서 속치마를 입는게 좋을듯 해요!
#  다른 컬러도 살예정ㅋㅋ</p>,
#  <span class="text-body_13px_reg sc-jEABJj eDGVAa gtm-click-button text-gray-600 font-pretendard" data-brand-id="(not set)" data-button-id="review_more" data-button-name="후기내용더보기" data-index="(not set)" data-section-index="6" data-section-name="review">... <span class="underline">더보기</span></span>,
#  <span class="text-body_13px_reg font-pretendard">28</span>,
#  <span class="text-body_13px_reg font-pretendard">0</span>,
#  <span class="text-body_13px_reg text-gray-600 font-pretendard">여성</span>,
#  <span class="text-body_13px_reg text-gray-600 font-pretendard">163(cm)</span>,
#  <span class="text-body_13px_reg text-gray-600 font-pretendard">60(kg)</span>,
#  <span class="text-body_13px_reg text-gray-600 font-pretendard">/</span>,
#  <span class="text-body_13px_reg text-gray-600 font-pretendard">M 구매</span>,
#  <span class="text-body_13px_reg sc-fXSgRJ fCtvvK text-gray-600 font-pretendard">21.05.11</span>,
#  <p class="text-body_13px_reg sc-cwHqhk jfrxJQ font-pretendard">통통한 편인데 엠사이즈 잘맞아요
#  딱 기본 스타일이라서 매우 맘에 듭니다</p>,
#  <span class="text-body_13px_reg font-pretendard">27</span>,
#  <span class="text-body_13px_reg font-pretendard">1</span>]

# %%
star_elements = soup.select('.text-body_14px_semi')
star_elements
# Out:
# [<span class="text-body_14px_semi font-pretendard">5.0</span>,
#  <span class="text-body_14px_semi font-pretendard">5.0</span>,
#  <span class="text-body_14px_semi font-pretendard">5.0</span>,
#  <span class="text-body_14px_semi font-pretendard">5.0</span>,
#  <span class="text-body_14px_semi font-pretendard">5.0</span>,
#  <span class="text-body_14px_semi font-pretendard">5.0</span>]

# %%
# HTTP 요청
url = 'https://search.musinsa.com/ranking/best?period=week&age=ALL&mainCategory=001&subCategory=&leafCategory=&price=&golf=false&kids=false&newProduct=false&exclusive=false&discount=false&soldOut=false&page=1&viewType=small&priceMin=&priceMax='
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

response = requests.get(url, headers=headers)
html = BeautifulSoup(response.text, 'html.parser')

# %%
driver = webdriver.Chrome()
url = 'https://www.musinsa.com/main/musinsa/ranking?storeCode=musinsa&sectionId=199&categoryCode=100000&period=MONTHLY'
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}


driver.get('https://www.naver.com')

# %%
import pandas as pd
import re
from selenium import webdriver
from bs4 import BeautifulSoup
import time

# 리뷰 수 추출 함수 정의
def extract_review_count(text):
    text = text.replace(',', '')
    match = re.search(r'\d+', text)
    if match:
        return int(match.group())
    else:
        return 0
        
# 리뷰 수집 함수 정의
def collect_reviews(product_url, product_id):
    driver = webdriver.Chrome()
    driver.implicitly_wait(10)
    
    driver.get(product_url)
    time.sleep(3)

    detail_html = driver.page_source
    soup = BeautifulSoup(detail_html, 'lxml')

    count = soup.select('.text-title_18px_med')
    if count:
        review_text = count[0].text
        review_count = extract_review_count(review_text)
    else:
        review_count = 0

    # 리뷰수 100개 이상일 때 수집 진행
    if review_count >= 100:
        # 제목 추출
        title_element = soup.select_one('.sc-eulNPF')
        title = title_element.text if title_element else 'None'
        
        filtered_reviews = []
        collected_reviews = 0

        # 페이지 높이 초기화
        last_height = driver.execute_script("return document.body.scrollHeight")

        while collected_reviews < 1000:
            # 페이지 소스 가져오기 및 파싱
            detail_html = driver.page_source
            soup = BeautifulSoup(detail_html, 'lxml')

            # 리뷰와 별점을 각각 다른 클래스에서 수집
            review_elements = soup.select(".sc-bbSYpP p")  # 리뷰 텍스트가 있는 요소
            star_elements = soup.select('.text-body_14px_semi')  # 별점이 있는 요소

            # 리뷰 - 별점 같은 수량인지 확인
            min_length = min(len(review_elements), len(star_elements))
            
            for i in range(min_length):
                review_text = review_elements[i].text.strip()
                star = star_elements[i].text.strip()
                
                filtered_reviews.append({"Review": review_text, "Star": star})
                collected_reviews += 1
            
        
            # 1000개 리뷰 수집 시 종료
            if collected_reviews >= 1000:
                break
    
            # 페이지 끝까지 스크롤
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(2)  # 스크롤 후 대기

            # 스크롤이 끝났을 시 종료 / 새로운 페이지 높이 계산
            new_height = driver.execute_script("return document.body.scrollHeight") # 높이비교
            if new_height == last_height:
                # 더 이상 스크롤할 내용이 없는 경우 종료
                print("더 이상 스크롤할 내용이 없으므로 종료합니다.")
                break
            last_height = new_height # 높이 업데이트
        
        driver.quit()
    
        # 수집된 리뷰, 별점을 DataFrame으로 변환하고 CSV 파일로 저장
        df_reviews = pd.DataFrame(filtered_reviews, columns=["Review", "Star"])
        csv_filename = f'reviews_{product_id}.csv'
        df_reviews.to_csv(csv_filename, index=False)
    
        print(f"총 수집된 리뷰 개수: {collected_reviews}")
        print(f"CSV 파일로 저장 완료: {csv_filename}")

        return {'Product ID': product_id, 'Title': title, 'Review Count': collected_reviews}

    else:
        print(f"{product_id}의 리뷰 수가 {review_count}개로 100개 미만이므로 수집하지 않습니다.")
    
    driver.quit()
    return None

df_links = pd.read_csv('musinsa_crawling_linklist.csv')

# Product ID 추출
df_links['Product ID'] = df_links['review URL'].str.extract(r'/goods/(\d+)$')

summary_list = []

# 상위 n개 링크에 대해 리뷰 수집
for index, row in df_links.iterrows():
    summary_data = collect_reviews(row['review URL'], row['Product ID'])
    if summary_data:
        summary_list.append(summary_data)

# 전체 summary_df 생성
summary_df = pd.DataFrame(summary_list)

# 전체 summary_df를 CSV 파일로 저장
summary_df.to_csv('overall_summary.csv', index=False)
print(f"전체 요약 CSV 파일로 저장 완료: overall_summary.csv")
# Out:
# 총 수집된 리뷰 개수: 1002
# CSV 파일로 저장 완료: reviews_1875663.csv
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 227
# CSV 파일로 저장 완료: reviews_3977452.csv
# 총 수집된 리뷰 개수: 1004
# CSV 파일로 저장 완료: reviews_1875664.csv
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 401
# CSV 파일로 저장 완료: reviews_4018731.csv
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 165
# CSV 파일로 저장 완료: reviews_3977488.csv
# 총 수집된 리뷰 개수: 1006
# CSV 파일로 저장 완료: reviews_2551401.csv
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 816
# CSV 파일로 저장 완료: reviews_2978106.csv
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 236
# CSV 파일로 저장 완료: reviews_3295891.csv
# 4234927의 리뷰 수가 9개로 100개 미만이므로 수집하지 않습니다.
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 956
# CSV 파일로 저장 완료: reviews_1645762.csv
# 4341683의 리뷰 수가 0개로 100개 미만이므로 수집하지 않습니다.
# 총 수집된 리뷰 개수: 1014
# CSV 파일로 저장 완료: reviews_1944554.csv
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 689
# CSV 파일로 저장 완료: reviews_2792603.csv
# 총 수집된 리뷰 개수: 1005
# CSV 파일로 저장 완료: reviews_1931894.csv
# 3906921의 리뷰 수가 72개로 100개 미만이므로 수집하지 않습니다.
# 3917556의 리뷰 수가 55개로 100개 미만이므로 수집하지 않습니다.
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 852
# CSV 파일로 저장 완료: reviews_2300718.csv
# 3403231의 리뷰 수가 44개로 100개 미만이므로 수집하지 않습니다.
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 825
# CSV 파일로 저장 완료: reviews_3051711.csv
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 266
# CSV 파일로 저장 완료: reviews_3850173.csv
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 872
# CSV 파일로 저장 완료: reviews_3753558.csv
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 285
# CSV 파일로 저장 완료: reviews_4018732.csv
# 4254226의 리뷰 수가 4개로 100개 미만이므로 수집하지 않습니다.
# 4154987의 리뷰 수가 74개로 100개 미만이므로 수집하지 않습니다.
# 4088113의 리뷰 수가 39개로 100개 미만이므로 수집하지 않습니다.
# 4170370의 리뷰 수가 51개로 100개 미만이므로 수집하지 않습니다.
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 533
# CSV 파일로 저장 완료: reviews_3753562.csv
# 3322615의 리뷰 수가 86개로 100개 미만이므로 수집하지 않습니다.
# 4037442의 리뷰 수가 11개로 100개 미만이므로 수집하지 않습니다.
# 총 수집된 리뷰 개수: 1009
# CSV 파일로 저장 완료: reviews_1645760.csv
# 3917557의 리뷰 수가 56개로 100개 미만이므로 수집하지 않습니다.
# 3971357의 리뷰 수가 5개로 100개 미만이므로 수집하지 않습니다.
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 761
# CSV 파일로 저장 완료: reviews_3325011.csv
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 193
# CSV 파일로 저장 완료: reviews_4135237.csv
# 4088117의 리뷰 수가 28개로 100개 미만이므로 수집하지 않습니다.
# 4107519의 리뷰 수가 32개로 100개 미만이므로 수집하지 않습니다.
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 918
# CSV 파일로 저장 완료: reviews_2551406.csv
# 3907183의 리뷰 수가 83개로 100개 미만이므로 수집하지 않습니다.
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 877
# CSV 파일로 저장 완료: reviews_2551407.csv
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 333
# CSV 파일로 저장 완료: reviews_3820464.csv
# 3906947의 리뷰 수가 32개로 100개 미만이므로 수집하지 않습니다.
# 총 수집된 리뷰 개수: 1013
# CSV 파일로 저장 완료: reviews_2306207.csv
# 4292856의 리뷰 수가 0개로 100개 미만이므로 수집하지 않습니다.
# 3179754의 리뷰 수가 2개로 100개 미만이므로 수집하지 않습니다.
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 906
# CSV 파일로 저장 완료: reviews_2117256.csv
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 738
# CSV 파일로 저장 완료: reviews_2448899.csv
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 410
# CSV 파일로 저장 완료: reviews_2978103.csv
# 총 수집된 리뷰 개수: 1007
# CSV 파일로 저장 완료: reviews_2117249.csv
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 423
# CSV 파일로 저장 완료: reviews_3051712.csv
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 450
# CSV 파일로 저장 완료: reviews_2978104.csv
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 212
# CSV 파일로 저장 완료: reviews_3925079.csv
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 401
# CSV 파일로 저장 완료: reviews_3757209.csv
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 432
# CSV 파일로 저장 완료: reviews_3263886.csv
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 273
# CSV 파일로 저장 완료: reviews_3511194.csv
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 238
# CSV 파일로 저장 완료: reviews_3902122.csv
# 총 수집된 리뷰 개수: 1000
# CSV 파일로 저장 완료: reviews_2392491.csv
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 270
# CSV 파일로 저장 완료: reviews_3590873.csv
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 473
# CSV 파일로 저장 완료: reviews_3135592.csv
# 3171883의 리뷰 수가 87개로 100개 미만이므로 수집하지 않습니다.
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 162
# CSV 파일로 저장 완료: reviews_3933048.csv
# 4292846의 리뷰 수가 0개로 100개 미만이므로 수집하지 않습니다.
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 566
# CSV 파일로 저장 완료: reviews_2551402.csv
# 4212671의 리뷰 수가 11개로 100개 미만이므로 수집하지 않습니다.
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 466
# CSV 파일로 저장 완료: reviews_3225475.csv
# 3971726의 리뷰 수가 6개로 100개 미만이므로 수집하지 않습니다.
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 749
# CSV 파일로 저장 완료: reviews_2533425.csv
# 4356172의 리뷰 수가 0개로 100개 미만이므로 수집하지 않습니다.
# 4339404의 리뷰 수가 1개로 100개 미만이므로 수집하지 않습니다.
# 3969465의 리뷰 수가 7개로 100개 미만이므로 수집하지 않습니다.
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 207
# CSV 파일로 저장 완료: reviews_3863284.csv
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 763
# CSV 파일로 저장 완료: reviews_1779568.csv
# 3758432의 리뷰 수가 81개로 100개 미만이므로 수집하지 않습니다.
# 4095421의 리뷰 수가 48개로 100개 미만이므로 수집하지 않습니다.
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 243
# CSV 파일로 저장 완료: reviews_3144417.csv
# 총 수집된 리뷰 개수: 1009
# CSV 파일로 저장 완료: reviews_2362073.csv
# 4068489의 리뷰 수가 45개로 100개 미만이므로 수집하지 않습니다.
# 4175670의 리뷰 수가 12개로 100개 미만이므로 수집하지 않습니다.
# 4339381의 리뷰 수가 0개로 100개 미만이므로 수집하지 않습니다.
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 564
# CSV 파일로 저장 완료: reviews_2725422.csv
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 400
# CSV 파일로 저장 완료: reviews_2533486.csv
# 3243818의 리뷰 수가 14개로 100개 미만이므로 수집하지 않습니다.
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 566
# CSV 파일로 저장 완료: reviews_2792604.csv
# 총 수집된 리뷰 개수: 1010
# CSV 파일로 저장 완료: reviews_1944553.csv
# 4053229의 리뷰 수가 30개로 100개 미만이므로 수집하지 않습니다.
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 437
# CSV 파일로 저장 완료: reviews_3231222.csv
# 4012720의 리뷰 수가 24개로 100개 미만이므로 수집하지 않습니다.
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 446
# CSV 파일로 저장 완료: reviews_2448902.csv
# 4170371의 리뷰 수가 22개로 100개 미만이므로 수집하지 않습니다.
# 3977541의 리뷰 수가 70개로 100개 미만이므로 수집하지 않습니다.
# 4265733의 리뷰 수가 1개로 100개 미만이므로 수집하지 않습니다.
# 3848109의 리뷰 수가 2개로 100개 미만이므로 수집하지 않습니다.
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 254
# CSV 파일로 저장 완료: reviews_3393420.csv
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 297
# CSV 파일로 저장 완료: reviews_2257612.csv
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 213
# CSV 파일로 저장 완료: reviews_3801258.csv
# 4153604의 리뷰 수가 39개로 100개 미만이므로 수집하지 않습니다.
# 4036171의 리뷰 수가 23개로 100개 미만이므로 수집하지 않습니다.
# 4101346의 리뷰 수가 28개로 100개 미만이므로 수집하지 않습니다.
# 3890916의 리뷰 수가 3개로 100개 미만이므로 수집하지 않습니다.
# 3969611의 리뷰 수가 10개로 100개 미만이므로 수집하지 않습니다.
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 453
# CSV 파일로 저장 완료: reviews_2117257.csv
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 283
# CSV 파일로 저장 완료: reviews_3425498.csv
# 4239931의 리뷰 수가 0개로 100개 미만이므로 수집하지 않습니다.
# 3784436의 리뷰 수가 61개로 100개 미만이므로 수집하지 않습니다.
# 4342208의 리뷰 수가 1개로 100개 미만이므로 수집하지 않습니다.
# 4260722의 리뷰 수가 1개로 100개 미만이므로 수집하지 않습니다.
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 491
# CSV 파일로 저장 완료: reviews_2117254.csv
# 4200576의 리뷰 수가 21개로 100개 미만이므로 수집하지 않습니다.
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 180
# CSV 파일로 저장 완료: reviews_3972174.csv
# 4146791의 리뷰 수가 60개로 100개 미만이므로 수집하지 않습니다.
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 153
# CSV 파일로 저장 완료: reviews_3758436.csv
# 4135439의 리뷰 수가 10개로 100개 미만이므로 수집하지 않습니다.
# 3993685의 리뷰 수가 31개로 100개 미만이므로 수집하지 않습니다.
# 4342169의 리뷰 수가 0개로 100개 미만이므로 수집하지 않습니다.
# 3345173의 리뷰 수가 4개로 100개 미만이므로 수집하지 않습니다.
# 4118529의 리뷰 수가 17개로 100개 미만이므로 수집하지 않습니다.
# 4212373의 리뷰 수가 5개로 100개 미만이므로 수집하지 않습니다.
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 181
# CSV 파일로 저장 완료: reviews_3774994.csv
# 3900612의 리뷰 수가 65개로 100개 미만이므로 수집하지 않습니다.
# 총 수집된 리뷰 개수: 1003
# CSV 파일로 저장 완료: reviews_2117253.csv
# 4101425의 리뷰 수가 32개로 100개 미만이므로 수집하지 않습니다.
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 162
# CSV 파일로 저장 완료: reviews_3512402.csv
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 211
# CSV 파일로 저장 완료: reviews_3295890.csv
# 4193422의 리뷰 수가 34개로 100개 미만이므로 수집하지 않습니다.
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 484
# CSV 파일로 저장 완료: reviews_1455772.csv
# 4062895의 리뷰 수가 21개로 100개 미만이므로 수집하지 않습니다.
# 4257818의 리뷰 수가 0개로 100개 미만이므로 수집하지 않습니다.
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 196
# CSV 파일로 저장 완료: reviews_2978589.csv
# 4146787의 리뷰 수가 33개로 100개 미만이므로 수집하지 않습니다.
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 191
# CSV 파일로 저장 완료: reviews_2978587.csv
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 358
# CSV 파일로 저장 완료: reviews_2500573.csv
# 3136176의 리뷰 수가 25개로 100개 미만이므로 수집하지 않습니다.
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 225
# CSV 파일로 저장 완료: reviews_3379470.csv
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 370
# CSV 파일로 저장 완료: reviews_2551409.csv
# 4060700의 리뷰 수가 20개로 100개 미만이므로 수집하지 않습니다.
# 3322824의 리뷰 수가 20개로 100개 미만이므로 수집하지 않습니다.
# 3932387의 리뷰 수가 7개로 100개 미만이므로 수집하지 않습니다.
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 330
# CSV 파일로 저장 완료: reviews_2245440.csv
# 3448351의 리뷰 수가 56개로 100개 미만이므로 수집하지 않습니다.
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 211
# CSV 파일로 저장 완료: reviews_3109155.csv
# 3861416의 리뷰 수가 31개로 100개 미만이므로 수집하지 않습니다.
# 3972973의 리뷰 수가 22개로 100개 미만이므로 수집하지 않습니다.
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 225
# CSV 파일로 저장 완료: reviews_3758458.csv
# 4130230의 리뷰 수가 28개로 100개 미만이므로 수집하지 않습니다.
# 3955789의 리뷰 수가 4개로 100개 미만이므로 수집하지 않습니다.
# 4065964의 리뷰 수가 10개로 100개 미만이므로 수집하지 않습니다.
# 4129517의 리뷰 수가 0개로 100개 미만이므로 수집하지 않습니다.
# 4060705의 리뷰 수가 21개로 100개 미만이므로 수집하지 않습니다.
# 4339400의 리뷰 수가 0개로 100개 미만이므로 수집하지 않습니다.
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 627
# CSV 파일로 저장 완료: reviews_2864414.csv
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 192
# CSV 파일로 저장 완료: reviews_2978108.csv
# 3130645의 리뷰 수가 58개로 100개 미만이므로 수집하지 않습니다.
# 4107456의 리뷰 수가 6개로 100개 미만이므로 수집하지 않습니다.
# 총 수집된 리뷰 개수: 1001
# CSV 파일로 저장 완료: reviews_2836289.csv
# 2827957의 리뷰 수가 8개로 100개 미만이므로 수집하지 않습니다.
# 4201903의 리뷰 수가 1개로 100개 미만이므로 수집하지 않습니다.
# 4088118의 리뷰 수가 8개로 100개 미만이므로 수집하지 않습니다.
# 3858290의 리뷰 수가 43개로 100개 미만이므로 수집하지 않습니다.
# 3442340의 리뷰 수가 7개로 100개 미만이므로 수집하지 않습니다.
# 4231266의 리뷰 수가 2개로 100개 미만이므로 수집하지 않습니다.
# 3511186의 리뷰 수가 86개로 100개 미만이므로 수집하지 않습니다.
# 3639483의 리뷰 수가 12개로 100개 미만이므로 수집하지 않습니다.
# 3250317의 리뷰 수가 89개로 100개 미만이므로 수집하지 않습니다.
# 3130633의 리뷰 수가 77개로 100개 미만이므로 수집하지 않습니다.
# 3874162의 리뷰 수가 7개로 100개 미만이므로 수집하지 않습니다.
# 4341707의 리뷰 수가 0개로 100개 미만이므로 수집하지 않습니다.
# 4170372의 리뷰 수가 16개로 100개 미만이므로 수집하지 않습니다.
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 284
# CSV 파일로 저장 완료: reviews_2593051.csv
# 3971203의 리뷰 수가 20개로 100개 미만이므로 수집하지 않습니다.
# 3891800의 리뷰 수가 12개로 100개 미만이므로 수집하지 않습니다.
# 4137462의 리뷰 수가 2개로 100개 미만이므로 수집하지 않습니다.
# 4032881의 리뷰 수가 9개로 100개 미만이므로 수집하지 않습니다.
# 3347453의 리뷰 수가 3개로 100개 미만이므로 수집하지 않습니다.
# 3921342의 리뷰 수가 13개로 100개 미만이므로 수집하지 않습니다.
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 182
# CSV 파일로 저장 완료: reviews_2978588.csv
# 3196505의 리뷰 수가 4개로 100개 미만이므로 수집하지 않습니다.
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 541
# CSV 파일로 저장 완료: reviews_1659998.csv
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 179
# CSV 파일로 저장 완료: reviews_3774993.csv
# 3819866의 리뷰 수가 62개로 100개 미만이므로 수집하지 않습니다.
# 3845243의 리뷰 수가 57개로 100개 미만이므로 수집하지 않습니다.
# 3524288의 리뷰 수가 57개로 100개 미만이므로 수집하지 않습니다.
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 238
# CSV 파일로 저장 완료: reviews_2245439.csv
# 총 수집된 리뷰 개수: 1008
# CSV 파일로 저장 완료: reviews_1324169.csv
# 3943154의 리뷰 수가 58개로 100개 미만이므로 수집하지 않습니다.
# 3926490의 리뷰 수가 7개로 100개 미만이므로 수집하지 않습니다.
# 4212670의 리뷰 수가 4개로 100개 미만이므로 수집하지 않습니다.
# 4343512의 리뷰 수가 0개로 100개 미만이므로 수집하지 않습니다.
# 3182696의 리뷰 수가 1개로 100개 미만이므로 수집하지 않습니다.
# 4092994의 리뷰 수가 4개로 100개 미만이므로 수집하지 않습니다.
# 2848613의 리뷰 수가 52개로 100개 미만이므로 수집하지 않습니다.
# 3902073의 리뷰 수가 14개로 100개 미만이므로 수집하지 않습니다.
# 총 수집된 리뷰 개수: 1008
# CSV 파일로 저장 완료: reviews_2714524.csv
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 236
# CSV 파일로 저장 완료: reviews_3035265.csv
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 496
# CSV 파일로 저장 완료: reviews_2392492.csv
# 4175651의 리뷰 수가 8개로 100개 미만이므로 수집하지 않습니다.
# 4072942의 리뷰 수가 0개로 100개 미만이므로 수집하지 않습니다.
# 4101470의 리뷰 수가 49개로 100개 미만이므로 수집하지 않습니다.
# 3971202의 리뷰 수가 63개로 100개 미만이므로 수집하지 않습니다.
# 4056085의 리뷰 수가 48개로 100개 미만이므로 수집하지 않습니다.
# 4108244의 리뷰 수가 5개로 100개 미만이므로 수집하지 않습니다.
# 더 이상 스크롤할 내용이 없으므로 종료합니다.
# 총 수집된 리뷰 개수: 429
# CSV 파일로 저장 완료: reviews_2416846.csv
# 전체 요약 CSV 파일로 저장 완료: overall_summary.csv

# %%
summary_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product ID    87 non-null     object
#  1   Title         87 non-null     object
#  2   Review Count  87 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 2.2+ KB

# %%
summary_df
# Out:
#    Product ID                                     Title  Review Count
# 0     1875663                 [쿨탠다드] 우먼즈 피케 폴로 원피스 [블랙]          1002
# 1     3977452  GIRLFRIEND SLEEVELESS MINI DRESS (BLACK)           227
# 2     1875664                [쿨탠다드] 우먼즈 피케 폴로 원피스 [네이비]          1004
# 3     4018731            레이스 리본 마이크로 미니 쇼츠 팬츠 스커트 [화이트]           401
# 4     3977488  GIRLFRIEND SLEEVELESS MINI DRESS (WHITE)           165
# ..        ...                                       ...           ...
# 82    1324169                  우먼즈 플랫 테리 스웨트 롱 스커트 [블랙]          1008
# 83    2714524                 Punching Knit Dress BLACK          1008
# 84    3035265                  론아스 7992 스판데님 다크인디고 롱스커트           236
# 85    2392492                     우먼즈 슬릿 넥 폴로 원피스 [에그렛]           496
# 86    2416846                      플레어 코튼 미디 스커트 - 아이보리           429
#
# [87 rows x 3 columns]

# %%
summary_df['Review Count'].sum()
# Out:
# 44971

# %%
import pandas as pd
from selenium import webdriver
from bs4 import BeautifulSoup
import time

df = pd.read_csv('overall_summary.csv')

# %%
brand_names = []

for product_id in df['Product ID']:
    driver = webdriver.Chrome()
    driver.implicitly_wait(10) 

    product_url = f'https://www.musinsa.com/products/{product_id}'
    driver.get(product_url)
    time.sleep(3)

    # 페이지 소스 가져오기 및 파싱
    html = driver.page_source
    soup = BeautifulSoup(html, 'lxml')
    driver.quit()

    # 브랜드 이름 추출
    brandname_elements = soup.select('.text-sm')
    if brandname_elements:
        brand_name = brandname_elements[0].text.strip()
    else:
        brand_name = "Unknown"

    # 브랜드 이름을 리스트에 추가
    brand_names.append(brand_name)

# 추출한 브랜드 이름을 새로운 열로 추가
df['Brand Name'] = brand_names

# 결과를 CSV 파일로 저장
df.to_csv('overall_summary_with_brand.csv', index=False)
print(f"브랜드 이름이 추가된 CSV 파일로 저장 완료: overall_summary_with_brand.csv")
# Out:
# 브랜드 이름이 추가된 CSV 파일로 저장 완료: overall_summary_with_brand.csv

# %%
df.head(20)
# Out:
#     Product ID                                     Title  Review Count  \
# 0      1875663                 [쿨탠다드] 우먼즈 피케 폴로 원피스 [블랙]          1002
# 1      3977452  GIRLFRIEND SLEEVELESS MINI DRESS (BLACK)           227
# 2      1875664                [쿨탠다드] 우먼즈 피케 폴로 원피스 [네이비]          1004
# 3      4018731            레이스 리본 마이크로 미니 쇼츠 팬츠 스커트 [화이트]           401
# 4      3977488  GIRLFRIEND SLEEVELESS MINI DRESS (WHITE)           165
# 5      2551401                        우먼즈 슬릿 미니 스코츠 [블랙]          1006
# 6      2978106                   우먼즈 카고 맥시 스커트 [라이트 베이지]           816
# 7      3295891                                       NaN           236
# 8      1645762                        우먼즈 데님 미디 스커트 [크림]           956
# 9      1944554                    우먼즈 데님 미니 스커트 [워시드 블랙]          1014
# 10     2792603                           우먼즈 맥시 스커트 [블랙]           689
# 11     1931894                 우먼즈 하이 웨이스트 슬릿 롱 스커트 [블랙]          1005
# 12     2300718                    우먼즈 데님 미디 스커트 [워시드 블랙]           852
# 13     3051711                   우먼즈 데님 맥시 스커트 [미디엄 인디고]           825
# 14     3850173     [NF] 포멀 버튼 플리츠 미디 스커트 (GRAY)_F24QD871           266
# 15     3753558                              튜튜 팬츠 스커트 크림           872
# 16     4018732             레이스 리본 마이크로 미니 쇼츠 팬츠 스커트 [블랙]           285
# 17     3753562                              튜튜 팬츠 스커트 블랙           533
# 18     1645760                   우먼즈 데님 미디 스커트 [라이트 인디고]          1009
# 19     3325011                나일론 스토퍼 벌룬 슬리브리스 롱 원피스[차콜]           761
#
#      Brand Name
# 0   무신사 스탠다드 우먼
# 1           글로니
# 2   무신사 스탠다드 우먼
# 3     플레이스 스튜디오
# 4           글로니
# 5   무신사 스탠다드 우먼
# 6   무신사 스탠다드 우먼
# 7           글로니
# 8   무신사 스탠다드 우먼
# 9   무신사 스탠다드 우먼
# 10  무신사 스탠다드 우먼
# 11  무신사 스탠다드 우먼
# 12  무신사 스탠다드 우먼
# 13  무신사 스탠다드 우먼
# 14      네스티팬시클럽
# 15          러프넥
# 16    플레이스 스튜디오
# 17          러프넥
# 18  무신사 스탠다드 우먼
# 19        썸플레이스

# %%
df['Brand Name'].isna().sum()
# Out:
# 0

# %%
nan_rows = df[df['Title'].isna()]
nan_rows
# Out:
#     Product ID Title  Review Count   Brand Name
# 7      3295891   NaN           236          글로니
# 34     3511194   NaN           273        어반드레스
# 38     3135592   NaN           473  무신사 스탠다드 우먼
# 42     2533425   NaN           749           콜릿
# 51     3231222   NaN           437            랩
# 55     3801258   NaN           213         슈퍼서브
# 63     3512402   NaN           162      언노운 플라넷
# 65     1455772   NaN           484      낫 유어 로즈
# 77     2593051   NaN           284          링서울

# %%
# 안되는 페이지 확인하기
driver = webdriver.Chrome()
driver.implicitly_wait(10) 

product_url = 'https://www.musinsa.com/products/3295891'
driver.get(product_url)
time.sleep(3)

html = driver.page_source
soup = BeautifulSoup(html, 'lxml')
driver.quit()

# %%
title = soup.select_one('.text-lg')
title.text
# Out:
# 'RODEO TIERED RUFFLE SKIRT (BABY BLUE)'

# %%
# Title을 다시 크롤링하는 함수 정의
def update_title(product_id):
    driver = webdriver.Chrome()
    driver.implicitly_wait(10) 

    try:
        product_url = f'https://www.musinsa.com/products/{product_id}'
        driver.get(product_url)
        time.sleep(3)

        html = driver.page_source
        soup = BeautifulSoup(html, 'lxml')

        title_element = soup.select_one('.text-lg')
        if title_element:
            title = title_element.text.strip()
            if not title:  # title이 비어있는 경우
                title = np.nan
        else:
            title = np.nan  # title 요소가 없을 때
    except Exception as e:
        print(f"오류 발생: {e}")
        title = np.nan  # 에러가 발생할 경우에도 NaN으로 처리
    finally:
        driver.quit()

    return title

# CSV 파일에서 데이터 읽기
df = pd.read_csv('overall_summary_with_brand.csv')

# NaN 값을 가진 Title 열만 선택
nan_titles = df[df['Title'].isna()]

# NaN 값을 가진 각 Product ID에 대해 다시 크롤링
for index, row in nan_titles.iterrows():
    product_id = row['Product ID']
    
    # 새로운 title 가져오기
    new_title = update_title(product_id)
    
    # DataFrame에 업데이트
    df.at[index, 'Title'] = new_title

# 업데이트된 DataFrame을 CSV 파일로 저장
df.to_csv('overall_summary_updated.csv', index=False)
print(f"업데이트된 CSV 파일로 저장 완료: overall_summary_updated.csv")
# Out:
# 업데이트된 CSV 파일로 저장 완료: overall_summary_updated.csv

# %%
df
# Out:
#     Product ID                                     Title  Review Count  \
# 0      1875663                 [쿨탠다드] 우먼즈 피케 폴로 원피스 [블랙]          1002
# 1      3977452  GIRLFRIEND SLEEVELESS MINI DRESS (BLACK)           227
# 2      1875664                [쿨탠다드] 우먼즈 피케 폴로 원피스 [네이비]          1004
# 3      4018731            레이스 리본 마이크로 미니 쇼츠 팬츠 스커트 [화이트]           401
# 4      3977488  GIRLFRIEND SLEEVELESS MINI DRESS (WHITE)           165
# ..         ...                                       ...           ...
# 82     1324169                  우먼즈 플랫 테리 스웨트 롱 스커트 [블랙]          1008
# 83     2714524                 Punching Knit Dress BLACK          1008
# 84     3035265                  론아스 7992 스판데님 다크인디고 롱스커트           236
# 85     2392492                     우먼즈 슬릿 넥 폴로 원피스 [에그렛]           496
# 86     2416846                      플레어 코튼 미디 스커트 - 아이보리           429
#
#      Brand Name
# 0   무신사 스탠다드 우먼
# 1           글로니
# 2   무신사 스탠다드 우먼
# 3     플레이스 스튜디오
# 4           글로니
# ..          ...
# 82  무신사 스탠다드 우먼
# 83        어반드레스
# 84         맥우드건
# 85  무신사 스탠다드 우먼
# 86          로에일
#
# [87 rows x 4 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of     Product ID                                     Title  Review Count  \
# 0      1875663                 [쿨탠다드] 우먼즈 피케 폴로 원피스 [블랙]          1002
# 1      3977452  GIRLFRIEND SLEEVELESS MINI DRESS (BLACK)           227
# 2      1875664                [쿨탠다드] 우먼즈 피케 폴로 원피스 [네이비]          1004
# 3      4018731            레이스 리본 마이크로 미니 쇼츠 팬츠 스커트 [화이트]           401
# 4      3977488  GIRLFRIEND SLEEVELESS MINI DRESS (WHITE)           165
# ..         ...                                       ...           ...
# 82     1324169                  우먼즈 플랫 테리 스웨트 롱 스커트 [블랙]          1008
# 83     2714524                 Punching Knit Dress BLACK          1008
# 84     3035265                  론아스 7992 스판데님 다크인디고 롱스커트           236
# 85     2392492                     우먼즈 슬릿 넥 폴로 원피스 [에그렛]           496
# 86     2416846                      플레어 코튼 미디 스커트 - 아이보리           429
#
#      Brand Name
# 0   무신사 스탠다드 우먼
# 1           글로니
# 2   무신사 스탠다드 우먼
# 3     플레이스 스튜디오
# 4           글로니
# ..          ...
# 82  무신사 스탠다드 우먼
# 83        어반드레스
# 84         맥우드건
# 85  무신사 스탠다드 우먼
# 86          로에일
#
# [87 rows x 4 columns]>
