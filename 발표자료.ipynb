# %%
import pandas as pd
import ast

df = pd.read_csv('merged_reviews_with_answers1.csv')
df = df.drop(columns=['common_keywords_all'])
df = df.drop(columns=['common_keywords_3_plus'])
df = df.drop(columns=['Answer'])

for i in range(1, 5):
    keyword_col = f'keyword_{i}'
    df[f'{keyword_col}'] = df[keyword_col].apply(lambda x: [k.strip().lower() for k in x] if isinstance(x, list) else [k.strip().lower() for k in ast.literal_eval(x)] if pd.notna(x) else [])

df.head(5)
# Out:
#                                               Review  \
# 0                     예쁘고 질 좋아요 추천합니다! 무진장 세일때 잘 샀어요
# 1                            기본치마입니당 속옷색 주의하면 될거같아여요
# 2                           너무 하얀색아니고 적당한 크림색이라 좋습니다
# 3  매장에서 입어보고\n무신사 스토어에서 바로 구매\n배송받고 바로 입고\n나갔어요\n...
# 4  크지도 않고 작지도 않고 딱 맞네요. 구김이 두드러지는건 흰색이라 어쩔 수 없는 것...
#
#                            keyword_1                      keyword_2  \
# 0                   [무진장, 추천, 세일, 질]                  [무진장, 추천, 세일]
# 1                [주의, 기본, 속옷, 색, 치마]           [치마, 주의, 요요, 기본, 속옷]
# 2                         [하얀색, 크림색]          [크림색, 적당하다, 아니다, 하얀색]
# 3          [물다, 입어보다, 스토어, 매장, 배송받다]      [매장, 입어보다, 스토어, 물다, 배송받다]
# 4  [크다, 어울리다, 맞다, 두드러지다, 구김, 흰색, 작다]  [두드러지다, 어울리다, 크다, 흰색, 구김, 없다]
#
#                            keyword_3  \
# 0                      [추천, 무진장, 세일]
# 1               [주의, 치마, 요요, 속옷, 기본]
# 2            [크림, 색, 아니다, 적당하다, 하얀색]
# 3        [배송, 받다, 입어보다, 매장, 스토어, 물다]
# 4  [흰색, 어울리다, 맞다, 구김, 에나, 두드러지다, 어쩔]
#
#                                    keyword_4
# 0                              [무진장, 세일, 추천]
# 1                       [요요, 주의, 속옷, 기본, 치마]
# 2                       [하얀색, 아니다, 적당하다, 크림]
# 3                [스토어, 받다, 매장, 입어보다, 물다, 배송]
# 4  [두드러지다, 어쩔, 에나, 구김, 어울리다, 흰색, 없다, 크다, 맞다]

# %%
df.rename(columns={'keyword_1': 'Llama 3.1', 'keyword_2': 'KeyBERT', 'keyword_3': 'KLUE/BERT+KeyBERT', 'keyword_4': 'TF-IDF'}, inplace=True)
pd.set_option('display.max_colwidth', None)
df.head(10)
# Out:
#                                                                                                                       Review  \
# 0                                                                                             예쁘고 질 좋아요 추천합니다! 무진장 세일때 잘 샀어요
# 1                                                                                                    기본치마입니당 속옷색 주의하면 될거같아여요
# 2                                                                                                   너무 하얀색아니고 적당한 크림색이라 좋습니다
# 3                                                                       매장에서 입어보고\n무신사 스토어에서 바로 구매\n배송받고 바로 입고\n나갔어요\n완죤 조아요
# 4                                               크지도 않고 작지도 않고 딱 맞네요. 구김이 두드러지는건 흰색이라 어쩔 수 없는 것 같아요. 어디에나 잘 어울려서 자주 입을 것 같아요.
# 5                                                                                          사이즈 맞고 핏도 예쁘고 잘샀어요..원단도 탄탄하고 좋아요.
# 6  음...저는 약간 살짝 끼어요.\n몸이 불편하진 않은데 보기에는 조금 불편할 수 있을 것 같아서 한 사이즈 더 크게 살 걸 그랬나 생각은 했습니다.\n하지만, 색감도 예쁘구요, 신축성이 좀 있어서 편해요. 만족합니다.
# 7                                                                      s사이즈는 허리가 작아서 m샀는데 좀 크네용.\n여름엔 좀 춥고 봄,가을이 젤 좋을 것 같아요~
# 8                                77반 88에게 타이트하게 맞아요ㅋㅋ 이쁘고 핏하고 시원하지만 계속 숨참고 있어야 한다는 게 단점..ㅎ_ㅎ입니다\n그래도 잘 입고 다니고 있어요! 키는 163입니다
# 9                                                                                         예뻐요 생각했던 핏입니다 이런 스타일 옷 찾고 있었는데 좋아요
#
#                                    Llama 3.1  \
# 0                           [무진장, 추천, 세일, 질]
# 1                        [주의, 기본, 속옷, 색, 치마]
# 2                                 [하얀색, 크림색]
# 3                  [물다, 입어보다, 스토어, 매장, 배송받다]
# 4          [크다, 어울리다, 맞다, 두드러지다, 구김, 흰색, 작다]
# 5                         [원단, 사이즈, 탄탄하다, 핏]
# 6                                        [끼]
# 7       [m, 춥다, 크다, 허리, 봄, s사이즈, 작다, 여름, 가을]
# 8  [계속, 한다는, 시원하다, 맞다, 핏, 타이트, 단점, 키, 숨, 참고]
# 9                          [스타일, 찾다, 이렇다, 핏]
#
#                                 KeyBERT                   KLUE/BERT+KeyBERT  \
# 0                         [무진장, 추천, 세일]                       [추천, 무진장, 세일]
# 1                  [치마, 주의, 요요, 기본, 속옷]                [주의, 치마, 요요, 속옷, 기본]
# 2                 [크림색, 적당하다, 아니다, 하얀색]             [크림, 색, 아니다, 적당하다, 하얀색]
# 3             [매장, 입어보다, 스토어, 물다, 배송받다]         [배송, 받다, 입어보다, 매장, 스토어, 물다]
# 4         [두드러지다, 어울리다, 크다, 흰색, 구김, 없다]   [흰색, 어울리다, 맞다, 구김, 에나, 두드러지다, 어쩔]
# 5                [탄탄하다, 원단, 사이즈, 핏, 맞다]              [맞다, 핏, 원단, 사이즈, 탄탄하다]
# 6  [만족하다, 신축, 보기, 불편하다, 음서, 사이즈, 색감, 몸]  [색감, 만족하다, 사이즈, 편하다, 보기, 에는, 불편하다]
# 7             [여름, 사이즈, 작다, 허리, 크다, 추다]        [추다, 여름, 작다, 크다, s, 사이즈, 허리]
# 8                [키, 단점, 시원하다, 참고, 타이트]                 [시원하다, 타이트, 맞다, 단점]
# 9                   [스타일, 이렇다, 핏입니, 찾다]                 [핏입니, 스타일, 이렇다, 찾다]
#
#                                           TF-IDF
# 0                                  [무진장, 세일, 추천]
# 1                           [요요, 주의, 속옷, 기본, 치마]
# 2                           [하얀색, 아니다, 적당하다, 크림]
# 3                    [스토어, 받다, 매장, 입어보다, 물다, 배송]
# 4      [두드러지다, 어쩔, 에나, 구김, 어울리다, 흰색, 없다, 크다, 맞다]
# 5                            [원단, 탄탄하다, 맞다, 사이즈]
# 6  [불편하다, 음서, 보기, 끼다, 그렇다, 크게, 에는, 신축, 색감, 만족하다]
# 7                      [추다, 작다, 여름, 크다, 허리, 사이즈]
# 8           [한다는, 계속, 단점, 참고, 타이트, 하고, 맞다, 시원하다]
# 9                            [핏입니, 이렇다, 찾다, 스타일]
